# %% [raw]
# ---
# author: "Joy Wang"
# title: "Preparing for the next class"
# description: "After taking UPenn's CIS 1600 course, the next class for me to take is then CIS 1210."
# date: "8 December 2025"
# categories:
#     - LLM
#     - Learning
#     - Math
# ---
