# %% [raw]
# ---
# author: "Joy Wang"
# title: "It's timeeee!"
# description: "It just snowed today! And with it, the winter season is clearly upon us even though I have no large scarf."
# date: "14 December 2025"
# categories:
#     - Crochet
#     - LLMs
#     - Hobbies
# ---
