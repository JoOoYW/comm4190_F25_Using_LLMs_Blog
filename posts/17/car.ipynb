# %% [raw]
# ---
# author: "Joy Wang"
# date: "3 December 2025"
# title: "How to maintain a car"
# description: "I have a license but no car yet. I want to get a car but how do I make it last forever?"
# categories:
#     - Learning
#     - LLM
# ---

# %% [markdown]
# Cars
