# %% [raw]
# ---
# author: "Joy Wang"
# date: "15 December 2025"
# title: "The wonderful game that is Hades"
# description: "This game has a strategy I don't know about."
# categories:
#     - LLM
#     - Learning
#     - Hobby
# ---

# %% [markdown]
# asdasdasd
