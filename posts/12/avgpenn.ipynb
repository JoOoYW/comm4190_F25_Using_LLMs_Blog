# %% [raw]
# ---
# author: "Joy Wang"
# date: "17 November 2025"
# title: "The average University of Pennsylvania Student"
# description: "When you think of someone who goes to Penn, what do you envision? What would a chatbot envision?"
# categories:
#     - LLMs
#     - Chatbots
# ---
