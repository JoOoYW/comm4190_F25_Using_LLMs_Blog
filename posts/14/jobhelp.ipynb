# %% [raw]
# ---
# author: "Joy Wang"
# title: "A little help goes a long way"
# description: "I dread working during holidays. Even moreso when we have new shipment"
# date: "29 November 2025"
# categories:
#     - LLMs
#     - Learning
#     - Job
#     - Holidays
# ---
